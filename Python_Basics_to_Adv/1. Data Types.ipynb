# %% [markdown]
# # Title 1
# ## Title 2
# ### Title 3

# %%
print("Hello Sai")
# Out:
# Hello Sai

# %%
x = 5

print(x)
# Out:
# 5

# %%
student_name = "Sai Preetham"

print(student_name)
# Out:
# Sai Preetham

# %% [markdown]
# ### not to use :
#
# * variable should not start with a number ---> 7x = 35

# %%
a = "sai"
b = "krishna"

print(a,b)
# Out:
# sai krishna

# %%
x = 5
y = "sai preetham"

print("x :", x)
print(y)
# Out:
# x : 5
# sai preetham

# %%
x = 5
y = "sai preetham"

print("x :",x,"\n",y)
# Out:
# x : 5
#  sai preetham

# %%
x = 20
y = 30

print(x+y)
# Out:
# 50
