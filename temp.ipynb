# %%
temp = ("sai", "preetham", 5, 78.7)

temp.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 temp = ("sai", "preetham", 5, 78.7)
# ----> 3 temp.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
temp = ("sai", "preetham", 5, 78.7)
temp1 = list(temp)
temp1.pop()
print(temp1)
tuple(temp1)
# Out:
# ['sai', 'preetham', 5]
# ('sai', 'preetham', 5)
